# %%
import numpy as np
import scipy.constants as cst

# %% [markdown]
# Given the trap depth of $T_{depth} \approx 570 \,uK$, we want to compute the total power of the tweezer

# %%
waist = 580e-9 # m
wavelength_trap = 532e-9 # m

omega_0 = 2*np.pi * 751.527471e12 # Hz, 1S0 -> 1P1 frequency 171Yb
omega_trap = 2*np.pi * cst.c / wavelength_trap

Gamma = 29.13e6 # Hz

# %%
# Light shift in units of energy per unit intensity
# for far-off resonance regime
def light_shift(omega0)
